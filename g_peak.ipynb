# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
from scipy.signal import find_peaks, peak_prominences
import scipy as scipy
from scipy import optimize
from numpy import loadtxt
from lmfit import Model
from lmfit.models import LorentzianModel,PseudoVoigtModel
from numpy import exp, loadtxt, pi, sqrt
from scipy.optimize import curve_fit
from matplotlib.patches import Ellipse
from matplotlib.text import OffsetFrom
from sklearn.linear_model import LinearRegression 
import os
import peakutils
from peakutils.plot import plot as pplot
from matplotlib import pyplot
from brokenaxes import brokenaxes

# %%
#Se definen los arrays de las gráficas
x_i1 = []
y_n1 = []

with open('EEG-A_1%.txt','r') as csvfile:
    file = csv.reader(csvfile, delimiter='\t')
    for row in file:
        x_i1.append(float(row[0]))
        y_n1.append(float(row[1]))
        
    # Se coloca la gráfica en cero
    y_i1=[]
    for i in range(len(y_n1)):
        y_i1.append(y_n1[i]-min(y_n1))
    
    peaks = find_peaks(y_i1,prominence=30)[0]
    a1=[x_i1[j] for j in peaks]
    b1=[y_i1[j] for j in peaks]
    
    # Límite del fit 
    x1=[]
    y1=[]
    for k in range(len(x_i1)):
        if x_i1[k]>1500 and x_i1[k]<1750:
        #if x_i[k]>1530 and x_i[k]<1640:
            x1.append(x_i1[k])
            y1.append(y_i1[k])
            
# Fit Lorenziano 
def lorentzian(x, amp1, cen1, wid1):
    return (amp1*wid1**2/((x-cen1)**2+wid1**2))

gmodel = Model(lorentzian)
gmodel.param_names
gmodel.independent_vars
params1 = gmodel.make_params(cen1=2700, amp1=250, wid1=12)
result1 = gmodel.fit(y1, params1, x=x1)
cen_1 = result1.params['cen1'].value
amp_1=result1.params['amp1'].value
wid_1=result1.params['wid1'].value
werr_1=result1.params['wid1'].stderr
err_1 = result1.params['cen1'].stderr
print(cen_1)
print(wid_1)

n=3500
x_f1=[]
y_f1=[]
for j in range(n):
    if j>999:
        lorenz=amp_1*wid_1**2/((j-cen_1)**2+wid_1**2)
        x_f1.append(j)
        y_f1.append(lorenz)
# Out:
# 1577.1983618847935
# 37.517832752687255

# %%
#Se definen los arrays de las gráficas
x_i2 = []
y_n2 = []

with open('EEG-A_10%.txt','r') as csvfile:
    file = csv.reader(csvfile, delimiter='\t')
    for row in file:
        x_i2.append(float(row[0]))
        y_n2.append(float(row[1]))
        
    # Se coloca la gráfica en cero
    y_i2=[]
    for i in range(len(y_n2)):
        y_i2.append(y_n2[i]-min(y_n2))
    
    peaks = find_peaks(y_i2,prominence=30)[0]
    a2=[x_i2[j] for j in peaks]
    b2=[y_i2[j] for j in peaks]
    
    # Límite del fit 
    x2=[]
    y2=[]
    for k in range(len(x_i2)):
        if x_i2[k]>1500 and x_i2[k]<1750:
            x2.append(x_i2[k])
            y2.append(y_i2[k])
            
# Fit Lorenziano 
def lorentzian(x, amp2, cen2, wid2):
    return (amp2*wid2**2/((x-cen2)**2+wid2**2))

gmodel = Model(lorentzian)
gmodel.param_names
gmodel.independent_vars
params2 = gmodel.make_params(cen2=2700, amp2=250, wid2=12)
result2 = gmodel.fit(y2, params2, x=x2)
cen_2 = result2.params['cen2'].value
amp_2=result2.params['amp2'].value
wid_2=result2.params['wid2'].value
werr_2=result2.params['wid2'].stderr
err_2 = result2.params['cen2'].stderr
print(cen_2)
print(wid_2)

n=3500
x_f2=[]
y_f2=[]
for j in range(n):
    if j>999:
        lorenz=amp_2*wid_2**2/((j-cen_2)**2+wid_2**2)
        x_f2.append(j)
        y_f2.append(lorenz)
# Out:
# 1576.7166256461464
# -36.93649746161805

# %%
#Se definen los arrays de las gráficas
x_i3 = []
y_n3 = []

with open('EEG-A_25%.txt','r') as csvfile:
    file = csv.reader(csvfile, delimiter='\t')
    for row in file:
        x_i3.append(float(row[0]))
        y_n3.append(float(row[1]))
        
    # Se coloca la gráfica en cero
    y_i3=[]
    for i in range(len(y_n3)):
        y_i3.append(y_n3[i]-min(y_n3))
    
    peaks = find_peaks(y_i3,prominence=30)[0]
    a3=[x_i3[j] for j in peaks]
    b3=[y_i3[j] for j in peaks]
    
    # Límite del fit 
    x3=[]
    y3=[]
    for k in range(len(x_i3)):
        if x_i3[k]>1500 and x_i3[k]<1750:
            x3.append(x_i3[k])
            y3.append(y_i3[k])
            
# Fit Lorenziano 
def lorentzian(x, amp3, cen3, wid3):
    return (amp3*wid3**2/((x-cen3)**2+wid3**2))

gmodel = Model(lorentzian)
gmodel.param_names
gmodel.independent_vars
params3 = gmodel.make_params(cen3=2700, amp3=250, wid3=12)
result3 = gmodel.fit(y3, params3, x=x3)
cen_3 = result3.params['cen3'].value
amp_3=result3.params['amp3'].value
wid_3=result3.params['wid3'].value
werr_3=result3.params['wid3'].stderr
err_3= result3.params['cen3'].stderr
print(cen_3)
print(wid_3)

n=3500
x_f3=[]
y_f3=[]
for j in range(n):
    if j>999:
        lorenz=amp_3*wid_3**2/((j-cen_3)**2+wid_3**2)
        x_f3.append(j)
        y_f3.append(lorenz)
# Out:
# 1574.4854986909843
# 37.25361904954597

# %%
#Se definen los arrays de las gráficas
x_i4 = []
y_n4= []

with open('EEG-A_50%.txt','r') as csvfile:
    file = csv.reader(csvfile, delimiter='\t')
    for row in file:
        x_i4.append(float(row[0]))
        y_n4.append(float(row[1]))
        
    # Se coloca la gráfica en cero
    y_i4=[]
    for i in range(len(y_n4)):
        y_i4.append(y_n4[i]-min(y_n4))
    
    peaks = find_peaks(y_i4,prominence=30)[0]
    a4=[x_i4[j] for j in peaks]
    b4=[y_i4[j] for j in peaks]
    
    # Límite del fit 
    x4=[]
    y4=[]
    for k in range(len(x_i4)):
        if x_i4[k]>1500 and x_i4[k]<1750:
            x4.append(x_i4[k])
            y4.append(y_i4[k])
            
# Fit Lorenziano 
def lorentzian(x, amp4, cen4, wid4):
    return (amp4*wid4**2/((x-cen4)**2+wid4**2))

gmodel = Model(lorentzian)
gmodel.param_names
gmodel.independent_vars
params4 = gmodel.make_params(cen4=2700, amp4=250, wid4=12)
result4 = gmodel.fit(y4, params4, x=x4)
cen_4 = result4.params['cen4'].value
amp_4=result4.params['amp4'].value
wid_4=result4.params['wid4'].value
werr_4=result4.params['wid4'].stderr
err_4= result4.params['cen4'].stderr
print(cen_4)
print(wid_4)

n=3500
x_f4=[]
y_f4=[]
for j in range(n):
    if j>999:
        lorenz=amp_4*wid_4**2/((j-cen_4)**2+wid_4**2)
        x_f4.append(j)
        y_f4.append(lorenz)
# Out:
# 1570.4990045064749
# 36.96917546396131

# %%
#Se definen los arrays de las gráficas
x_i5 = []
y_n5 = []

with open('EEG-A_100%.txt','r') as csvfile:
    file = csv.reader(csvfile, delimiter='\t')
    for row in file:
        x_i5.append(float(row[0]))
        y_n5.append(float(row[1]))
        
    # Se coloca la gráfica en cero
    y_i5=[]
    for i in range(len(y_n5)):
        y_i5.append(y_n5[i]-min(y_n5))
    
    peaks = find_peaks(y_i5,prominence=50)[0]
    a5=[x_i5[j] for j in peaks]
    b5=[y_i5[j] for j in peaks]
    
    # Límite del fit 
    x5=[]
    y5=[]
    for k in range(len(x_i5)):
        if x_i5[k]>1500 and x_i5[k]<1750:
            x5.append(x_i5[k])
            y5.append(y_i5[k])
            
# Fit Lorenziano 
def lorentzian(x, amp5, cen5, wid5):
    return (amp5*wid5**2/((x-cen5)**2+wid5**2))

gmodel = Model(lorentzian)
gmodel.param_names
gmodel.independent_vars
params5 = gmodel.make_params(cen5=2700, amp5=250, wid5=12)
result5 = gmodel.fit(y5, params5, x=x5)
cen_5 = result5.params['cen5'].value
amp_5=result5.params['amp5'].value
wid_5=result5.params['wid5'].value
werr_5=result5.params['wid5'].stderr
err_5= result5.params['cen5'].stderr
print(cen_5)
print(wid_5)

n=3500
x_f5=[]
y_f5=[]
for j in range(n):
    if j>999:
        lorenz=amp_5*wid_5**2/((j-cen_5)**2+wid_5**2)
        x_f5.append(j)
        y_f5.append(lorenz)
# Out:
# 1565.6385004271363
# 35.76648943998051

# %%
#Creamos la grafica del raw data, con la linea base y ya sin la linea base.
pyplot.ion()
fig=pyplot.figure(figsize=(5,7))
pyplot.subplots_adjust(hspace=0)
fig.text(0.5, 0.04, 'Raman Shift [$cm^{-1}$]', ha='center', va='center',fontsize=12)
fig.text(0.02, 0.5, 'Intensity [Arb. Unit]', ha='center', va='center', rotation='vertical',fontsize=12)

ax1=fig.add_subplot(5,1,1)
ax2=fig.add_subplot(5,1,2)
ax3=fig.add_subplot(5,1,3)
ax4=fig.add_subplot(5,1,4)
ax5=fig.add_subplot(5,1,5)

bbox_props = dict(boxstyle="round", fc="w", ec="0.5", alpha=0.9)

ax1.plot(x_i1,y_i1,label='0.06mW')
ax1.plot(x_f1,y_f1)
ax1.legend(frameon=False)
ax1.text(2150, 200, "{0:.2f}".format(cen_1)+'$cm^{-1}$\n'+'FWHM={0:.2f}'.format(wid_5), ha="center", va="center", size=10,
        bbox=bbox_props)
ax1.annotate('D',
            xy=(a1[0], b1[0]), xycoords='data',
            xytext=(0.09, 0.85), textcoords='axes fraction',
            arrowprops=dict(arrowstyle="->",facecolor='black'),
            horizontalalignment='left', verticalalignment='bottom')
ax1.annotate('G',
            xy=(a1[1], b1[1]), xycoords='data',
            xytext=(0.175, 0.7), textcoords='axes fraction',
            arrowprops=dict(arrowstyle="->",facecolor='black'),
            horizontalalignment='left', verticalalignment='bottom')
ax1.annotate('2D',
            xy=(a1[2], b1[2]), xycoords='data',
            xytext=(0.71, 0.2), textcoords='axes fraction',
            arrowprops=dict(arrowstyle="->",facecolor='black'),
            horizontalalignment='left', verticalalignment='bottom')
#ax1.axvline(cen_1,linestyle='dotted',c='k')
fig.canvas.draw()
ax2.plot(x_i2,y_i2,label='0.62mW')
ax2.plot(x_f2,y_f2)
ax2.legend(frameon=False)
ax2.text(2150, 1700, "{0:.2f}".format(cen_2)+'$cm^{-1}$\n'+'FWHM={0:.2f}'.format(wid_2), ha="center", va="center", size=10,
        bbox=bbox_props)
ax2.annotate('D',
            xy=(a2[0], b2[0]), xycoords='data',
            xytext=(0.09, 0.85), textcoords='axes fraction',
            arrowprops=dict(arrowstyle="->",facecolor='black'),
            horizontalalignment='left', verticalalignment='bottom')
ax2.annotate('G',
            xy=(a2[1], b2[1]), xycoords='data',
            xytext=(0.175, 0.7), textcoords='axes fraction',
            arrowprops=dict(arrowstyle="->",facecolor='black'),
            horizontalalignment='left', verticalalignment='bottom')
ax2.annotate('2D',
            xy=(a2[2], b2[2]), xycoords='data',
            xytext=(0.71, 0.2), textcoords='axes fraction',
            arrowprops=dict(arrowstyle="->",facecolor='black'),
            horizontalalignment='left', verticalalignment='bottom')
#ax2.axvline(cen_2,linestyle='dotted',c='k')
fig.canvas.draw()
ax3.plot(x_i3,y_i3,label='1.56mW')
ax3.plot(x_f3,y_f3)
ax3.legend(frameon=False)
ax3.text(2150, 5000, "{0:.2f}".format(cen_3)+'$cm^{-1}$\n'+'FWHM={0:.2f}'.format(wid_3), ha="center", va="center", size=10,
        bbox=bbox_props)
ax3.annotate('D',
            xy=(a3[0], b3[0]), xycoords='data',
            xytext=(0.09, 0.85), textcoords='axes fraction',
            arrowprops=dict(arrowstyle="->",facecolor='black'),
            horizontalalignment='left', verticalalignment='bottom')
ax3.annotate('G',
            xy=(a3[1], b3[1]), xycoords='data',
            xytext=(0.175, 0.7), textcoords='axes fraction',
            arrowprops=dict(arrowstyle="->",facecolor='black'),
            horizontalalignment='left', verticalalignment='bottom')
ax3.annotate('2D',
            xy=(a3[2], b3[2]), xycoords='data',
            xytext=(0.71, 0.2), textcoords='axes fraction',
            arrowprops=dict(arrowstyle="->",facecolor='black'),
            horizontalalignment='left', verticalalignment='bottom')
#ax3.axvline(cen_3,linestyle='dotted',c='k')
fig.canvas.draw()
ax4.plot(x_i4,y_i4,label='3.12mW')
ax4.plot(x_f4,y_f4)
ax4.legend(frameon=False)
ax4.text(2150, 10000, "{0:.2f}".format(cen_4)+'$cm^{-1}$\n'+'FWHM={0:.2f}'.format(wid_4), ha="center", va="center", size=10,
        bbox=bbox_props)
ax4.annotate('D',
            xy=(a4[0], b4[0]), xycoords='data',
            xytext=(0.09, 0.85), textcoords='axes fraction',
            arrowprops=dict(arrowstyle="->",facecolor='black'),
            horizontalalignment='left', verticalalignment='bottom')
ax4.annotate('G',
            xy=(a4[1], b4[1]), xycoords='data',
            xytext=(0.175, 0.7), textcoords='axes fraction',
            arrowprops=dict(arrowstyle="->",facecolor='black'),
            horizontalalignment='left', verticalalignment='bottom')
ax4.annotate('2D',
            xy=(a4[2], b4[2]), xycoords='data',
            xytext=(0.71, 0.2), textcoords='axes fraction',
            arrowprops=dict(arrowstyle="->",facecolor='black'),
            horizontalalignment='left', verticalalignment='bottom')
#ax4.axvline(cen_4,linestyle='dotted',c='k')
fig.canvas.draw()
ax5.plot(x_i5,y_i5,label='6.25mW')
ax5.plot(x_f5,y_f5)
ax5.legend(frameon=False)
ax5.text(2150, 18000, "{0:.2f}".format(cen_5)+'$cm^{-1}$\n'+'FWHM={0:.2f}'.format(wid_5), ha="center", va="center", size=10,
        bbox=bbox_props)
ax5.annotate('D',
            xy=(a5[0], b5[0]), xycoords='data',
            xytext=(0.09, 0.85), textcoords='axes fraction',
            arrowprops=dict(arrowstyle="->",facecolor='black'),
            horizontalalignment='left', verticalalignment='bottom')
ax5.annotate('G',
            xy=(a5[1], b5[1]), xycoords='data',
            xytext=(0.175, 0.7), textcoords='axes fraction',
            arrowprops=dict(arrowstyle="->",facecolor='black'),
            horizontalalignment='left', verticalalignment='bottom')
ax5.annotate('2D',
            xy=(a5[2], b5[2]), xycoords='data',
            xytext=(0.71, 0.2), textcoords='axes fraction',
            arrowprops=dict(arrowstyle="->",facecolor='black'),
            horizontalalignment='left', verticalalignment='bottom')
#ax5.axvline(cen_5,linestyle='dotted',c='k')
fig.canvas.draw()

fig.savefig('g_peak.png',dpi=199)

# %%
cen=[cen_1,cen_2,cen_3,cen_4,cen_5]
err=[err_1,err_2,err_3,err_4,err_5]
inten=[1, 10, 25, 50, 100]
power=[]

for i in range(len(inten)):
    res=inten[i]*6.25/100
    power.append(float(res))

power = np.asarray(power)
power =power.reshape(-1, 1)

lineal = LinearRegression() 
lineal.fit(power, cen) 
w = lineal.coef_
b = "{0:.2f}".format(lineal.intercept_)
r2 = "{0:.2f}".format(lineal.score(power, cen))
#print(r2)

fig, ax = plt.subplots()
ax.set_title('G Peak')
ax.errorbar(power, cen, yerr=err,fmt='o')
ax.plot(power, float(lineal.intercept_)+float(lineal.coef_)*power,label='Linear fit')
ax.set_xlabel('Power [mW]')
ax.set_ylabel('Raman shift [$cm^{-1}$]')
ax.legend()
ax.annotate('y='+str("{0:.2f}".format(w[0]))+'x+'+str(b),
            xy=(0.15, 0.25), xycoords='axes fraction',
            xytext=(-20, 20), textcoords='offset pixels',
            horizontalalignment='left',
            verticalalignment='bottom')
ax.annotate('$r^{2}$='+str(r2),
            xy=(0.23, 0.15), xycoords='axes fraction',
            xytext=(-20, 20), textcoords='offset pixels',
            horizontalalignment='left',
            verticalalignment='bottom')
fig.savefig('Raman_C1_fit_g.png',dpi=199)
